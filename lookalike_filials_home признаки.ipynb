# %%
from my_functions import * #это коннектор к базе. там долго настраивать. выгрузи через бобра, сохрани в csv, загрузи в питон через pandas.read_csv или read_excel
import pandas as pd
from numpy import sin, cos, arccos, pi, round

def rad2deg(radians):
    degrees = radians * 180 / pi
    return degrees

def deg2rad(degrees):
    radians = degrees * pi / 180
    return radians

def getDistanceBetweenPointsNew(latitude1, longitude1, latitude2, longitude2, unit = 'kilometers'):
    
    theta = longitude1 - longitude2
    
    distance = 60 * 1.1515 * rad2deg(
        arccos(
            (sin(deg2rad(latitude1)) * sin(deg2rad(latitude2))) + 
            (cos(deg2rad(latitude1)) * cos(deg2rad(latitude2)) * cos(deg2rad(theta)))
        )
    )
    
    if unit == 'miles':
        return round(distance, 2)
    if unit == 'kilometers':
        return round(distance * 1.609344, 2)

# %%
scr="""
select distinct firms.city_id "CityID",firms.latitude ,firms.longitude,firms.id "FirmID"
from firm.firms firms
left join firm.fact_rubrics rubrics on firms.id=rubrics.firm_id 
left join firm.dim_rubrics on rubrics.rubric_id =dim_rubrics.id
left join firm.dim_cities_dwh cities on firms.city_id =cities."CityID" 
where 1=1
	--and firms.city_id =1995
	and firms.city_id_2gis =cities.id 
	and firms.topic='wildberries'
"""
dots=df_build('delta_bi',scr)
# Out:
#  - 0:00:01.093580 341

# %%
branches=create_branches()
# Out:
# branches_dnsdwh.sql - 0:00:03.618128 2688
#   филиалы-концентраторы - 0:00:01.605912 1008

# %%
temp=branches.merge(dots,on='CityID',how='inner')
temp_city=temp.groupby(['CityID'],as_index=False).FirmID.nunique()
temp_city=temp_city.rename(columns={'FirmID':'city_cnt'})

temp['distance']=getDistanceBetweenPointsNew(temp.latitude_x,temp.longitude_x,temp.latitude_y,temp.longitude_y)
temp=temp.query('distance<=1').groupby(['BranchCode','CityID'],as_index=False).distance.count()
temp=temp.rename(columns={'distance':'km1_cnt'})

temp=branches.merge(temp,on=['BranchCode','CityID'],how='left').merge(temp_city,on='CityID',how='left').query('StoreName=="Иркутск Склад"')
temp['cut']=temp.km1_cnt/temp.city_cnt
temp=temp.fillna(0)
temp
# Out:
#                                 pred_guid BranchCode  BranchID  \
# 364  150004b7-ce5d-0058-11ed-d1d4f3f89c54       6447      7111
# 365  150025b7-ce5d-0058-11ed-f48ebf2a05fa       6511      7175
# 366  0000b687-191a-df33-11db-ed4a9588d1b2         43       254
# 367  150023b6-ce5d-0058-11ec-ee150af6af3d       6175      6837
# 368  150012b7-ce5d-0058-11ed-df264a63578f       6479      7143
# 369  150085b5-ce5d-0058-11ec-4b3a8b3c6010       5916      6584
# 370  15007cb5-ce5d-0058-11ec-4138a1100e15       5894      6556
# 371  150078b5-ce5d-0058-11ec-3ad76dedda6c       5875      6537
# 372  150069b5-ce5d-0058-11ec-2d6293182017       5829      6496
# 373  150042b5-ce5d-0058-11ec-0712608065bf       5721      6390
# 374  15005ab5-ce5d-0058-11ec-1f4393717937       5789      6454
# 375  150019b5-ce5d-0058-11eb-d965302b3c3b       5585      6255
# 376  15002fb5-ce5d-0058-11eb-f365a21a2da6       5654      6318
# 377  15001aa2-215d-084d-11eb-3867d66d2c23       4919      5581
# 393  1801ad74-f9f8-11e0-bb05-001517c526f0
# 394  1801ad74-f9f8-11e0-bb05-001517c526f0
# 395  1801ad74-f9f8-11e0-bb05-001517c526f0
# 396  1801ad74-f9f8-11e0-bb05-001517c526f0
# 397  1801ad74-f9f8-11e0-bb05-001517c526f0
# 398  1801ad74-f9f8-11e0-bb05-001517c526f0
# 399  1801ad74-f9f8-11e0-bb05-001517c526f0
# 400  1801ad74-f9f8-11e0-bb05-001517c526f0
# 401  1801ad74-f9f8-11e0-bb05-001517c526f0
# 402  1801ad74-f9f8-11e0-bb05-001517c526f0
# 403  1801ad74-f9f8-11e0-bb05-001517c526f0
# 404  1801ad74-f9f8-11e0-bb05-001517c526f0
# 405  1801ad74-f9f8-11e0-bb05-001517c526f0
# 406  1801ad74-f9f8-11e0-bb05-001517c526f0
# 407  1801ad74-f9f8-11e0-bb05-001517c526f0
# 408  1801ad74-f9f8-11e0-bb05-001517c526f0
# 409  1801ad74-f9f8-11e0-bb05-001517c526f0
# 410  1801ad74-f9f8-11e0-bb05-001517c526f0
#
#                                store_guid DivisionID                 citytype  \
# 364  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 365  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 366  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 367  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 368  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 369  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 370  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 371  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 372  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 373  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2          рабочий поселок
# 374  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 375  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 376  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 377  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 378  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                     село
# 379  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 380  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 381  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2          рабочий поселок
# 382  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 383  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 384  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                  поселок
# 385  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 386  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 387  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 388  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 389  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 390  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 391  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2  поселок городского типа
# 392  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 393  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                  поселок
# 394  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 395  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 396  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 397  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 398  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 399  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 400  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 401  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 402  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 403  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 404  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 405  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 406  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 407  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 408  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 409  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
# 410  b9f32b1a-9997-4e64-8cc3-64197b8a48cc          2                    город
#
#              cityname conc  km1_cnt city_cnt       cut
# 364           Иркутск  1.0      4.0    147.0  0.027211
# 365           Ангарск  1.0      1.0     45.0  0.022222
# 366           Иркутск  0.0      9.0    147.0  0.061224
# 367           Иркутск  0.0     10.0    147.0  0.068027
# 368          Улан-Удэ  1.0      1.0     80.0  0.012500
# 369           Иркутск  0.0      7.0    147.0  0.047619
# 370           Иркутск  0.0     12.0    147.0  0.081633
# 371         Байкальск  0.0      1.0      3.0  0.333333
# 372  Усолье-Сибирское  0.0      4.0     13.0  0.307692
# 373           Маркова  1.0      4.0     12.0  0.333333
# 374          Улан-Удэ  1.0      2.0     80.0  0.025000
# 375           Иркутск  1.0      6.0    147.0  0.040816
# 376             Тулун  0.0      1.0      2.0  0.500000
# 377          Улан-Удэ  0.0      2.0     80.0  0.025000
# 378          Хомутово  0.0      1.0      4.0  0.250000
# 379          Слюдянка  0.0      2.0      3.0  0.666667
# 380           Иркутск  0.0      3.0    147.0  0.020408
# 381            Залари  0.0      2.0      2.0  1.000000
# 382          Улан-Удэ  0.0      8.0     80.0  0.100000
# 383           Ангарск  0.0     10.0     45.0  0.222222
# 384             Бохан  0.0      0.0      0.0  0.000000
# 385      Гусиноозерск  0.0      5.0      5.0  1.000000
# 386          Улан-Удэ  0.0     12.0     80.0  0.150000
# 387           Иркутск  1.0      1.0    147.0  0.006803
# 388           Иркутск  0.0      1.0    147.0  0.006803
# 389            Саянск  0.0      0.0      1.0  0.000000
# 390           Ангарск  1.0     11.0     45.0  0.244444
# 391        Селенгинск  0.0      2.0      2.0  1.000000
# 392             Кяхта  0.0      2.0      3.0  0.666667
# 393    Усть-Ордынский  0.0      1.0      3.0  0.333333
# 394           Ангарск  0.0     11.0     45.0  0.244444
# 395              Зима  0.0      1.0      2.0  0.500000
# 396           Иркутск  1.0      3.0    147.0  0.020408
# 397  Усолье-Сибирское  0.0      4.0     13.0  0.307692
# 398           Иркутск  0.0      9.0    147.0  0.061224
# 399           Иркутск  0.0     10.0    147.0  0.068027
# 400           Ангарск  0.0      8.0     45.0  0.177778
# 401          Улан-Удэ  0.0      3.0     80.0  0.037500
# 402          Улан-Удэ  0.0      1.0     80.0  0.012500
# 403          Улан-Удэ  1.0      1.0     80.0  0.012500
# 404           Иркутск  0.0      5.0    147.0  0.034014
# 405           Иркутск  0.0      5.0    147.0  0.034014
# 406           Шелехов  0.0      3.0      8.0  0.375000
# 407           Иркутск  0.0      6.0    147.0  0.040816
# 408           Иркутск  0.0      0.0    147.0  0.000000
# 409         Черемхово  0.0      3.0      6.0  0.500000
# 410           Иркутск  1.0      1.0    147.0  0.006803
#
# [47 rows x 24 columns]

# %%
temp=branches.merge(dots,on='CityID',how='inner')
temp.query('CityID==1995').FirmID.unique()
# Out:
# array([70000001051432302, 70000001059349453, 70000001064709675,
#        70000001064785460, 70000001040972596, 70000001063127379,
#        70000001059349513, 70000001032095113, 70000001062384166,
#        70000001051407024, 70000001057678971, 70000001067117892,
#        70000001035818904, 70000001059349393, 70000001064333004,
#        70000001059349455, 70000001057370792, 70000001064525854,
#        70000001059349477, 70000001033581134, 70000001038371477,
#        70000001055628400, 70000001058975829, 70000001067863258,
#        70000001038371413, 70000001032520747, 70000001041734385,
#        70000001040485612, 70000001067878682, 70000001056833646,
#        70000001059873840, 70000001056984162, 70000001043390488,
#        70000001023171999, 70000001067255094, 70000001060312126,
#        70000001060352117, 70000001059774192, 70000001032095175,
#        70000001056820580, 70000001059725389, 70000001060038061,
#        70000001055345008, 70000001066796388, 70000001039111053,
#        70000001057455121, 70000001058983722, 70000001057818960,
#        70000001063836614, 70000001034792737, 70000001052315076,
#        70000001033684815, 70000001038279694, 70000001024911325,
#        70000001061595322, 70000001069402211, 70000001037554126,
#        70000001068901334, 70000001066513229, 70000001046883019,
#        70000001036063908, 70000001031307411, 70000001058975779,
#        70000001059065359, 70000001059349387, 70000001052311096,
#        70000001054852608, 70000001034673709, 70000001059384926,
#        70000001056586355, 70000001034792414, 70000001037363424,
#        70000001059349375, 70000001060732093, 70000001058656795,
#        70000001060269619, 70000001038371471, 70000001062389102,
#        70000001069500568, 70000001025575294, 70000001056822348,
#        70000001054337087, 70000001059309911, 70000001058637469,
#        70000001034443488, 70000001035794176, 70000001032094932,
#        70000001053107434, 70000001032095190, 70000001068795805,
#        70000001064190997, 70000001064641136, 70000001065952134,
#        70000001053935900, 70000001069134452, 70000001062383070,
#        70000001066889850, 70000001030550248, 70000001038371457,
#        70000001034792383, 70000001074989200, 70000001033331526,
#        70000001060602627, 70000001059704134, 70000001061409532,
#        70000001069056515, 70000001036582175, 70000001068997722,
#        70000001035995524, 70000001065503325, 70000001058760743,
#        70000001041077663, 70000001063364284, 70000001057455872,
#        70000001057006304, 70000001057215384, 70000001059349416,
#        70000001060960888, 70000001071482400, 70000001066698982,
#        70000001032669115, 70000001034792435, 70000001067930788,
#        70000001059912947, 70000001058833305, 70000001067897648,
#        70000001059349445, 70000001068718503, 70000001056382773,
#        70000001067298978, 70000001057211341, 70000001068207531,
#        70000001051468434, 70000001067379801, 70000001060804078,
#        70000001037221838, 70000001056709198, 70000001056009076,
#        70000001058976317, 70000001056287446, 70000001033425869,
#        70000001067232359, 70000001060858191, 70000001055963245,
#        70000001038888833, 70000001060733964, 70000001062390155],
#       dtype=int64)

# %%
features_orig=df_build('dns_dwh','lookalike_filials_feature')
features_orig.date_open=features_orig.date_open.astype('datetime64[ns]')

competitors=df_build('dns_dwh','lookalike_filials_competitors')
# Out:
# lookalike_filials_feature.sql - 0:00:01.248521

# %%
branches_dns=features_orig.groupby('CityID').BranchCode.count().reset_index()
branches_dns=branches_dns.rename(columns={'BranchCode':'branches_dns_in_city'})
features_orig=features_orig.merge(branches_dns,how='left',on='CityID')
del branches_dns

# %%
# другие филиалы ДНС поблизости
distance=features_orig.merge(features_orig[['longitude','latitude']],how='cross')
distance['distance']=getDistanceBetweenPointsNew(distance.latitude_x,distance.longitude_x,distance.latitude_y,distance.longitude_y)

# больше нуля - чтобы исключить сам магазин
temp=distance.query('distance>0 and distance<=1')
temp=temp.groupby('BranchCode').BranchID.count().reset_index()
temp=temp.rename(columns={'BranchID':'other_branches_dns_in_1km'})
features_orig=features_orig.merge(temp,how='left',on='BranchCode')
features_orig.other_branches_dns_in_1km=features_orig.other_branches_dns_in_1km.fillna(0)

temp=distance.query('distance>0 and distance<=3')
temp=temp.groupby('BranchCode').BranchID.count().reset_index()
temp=temp.rename(columns={'BranchID':'other_branches_dns_in_3km'})
features_orig=features_orig.merge(temp,how='left',on='BranchCode')
features_orig.other_branches_dns_in_3km=features_orig.other_branches_dns_in_3km.fillna(0)
# Out:
# C:\Users\Khramenkov.VV\Anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in arccos
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# расстояние до РРЦ
features_orig['distance_to_rrc']=getDistanceBetweenPointsNew(features_orig.store_latitude,features_orig.store_longitude,features_orig.latitude,features_orig.longitude)

# %%
# филиалы конкурентов поблизости

distance=features_orig[['BranchCode','longitude','latitude']].merge(competitors[['longitude','latitude']],how='cross')
distance['distance']=getDistanceBetweenPointsNew(distance.latitude_x,distance.longitude_x,distance.latitude_y,distance.longitude_y)


temp=distance.query('distance<=1')
temp=temp.groupby('BranchCode').longitude_x.count().reset_index()
temp=temp.rename(columns={'longitude_x':'competitors_in_1km'})
features_orig=features_orig.merge(temp,how='left',on='BranchCode')
features_orig.competitors_in_1km=features_orig.competitors_in_1km.fillna(0)

temp=distance.query('distance<=3')
temp=temp.groupby('BranchCode').longitude_x.count().reset_index()
temp=temp.rename(columns={'longitude_x':'competitors_in_3km'})
features_orig=features_orig.merge(temp,how='left',on='BranchCode')
features_orig.competitors_in_3km=features_orig.competitors_in_3km.fillna(0)
# Out:
# lookalike_filials_competitors.sql - 0:00:01.212715
